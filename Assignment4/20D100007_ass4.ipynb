# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2
from google.colab.patches import cv2_imshow

# %%
df = cv2.imread("/content/drive/MyDrive/EE610-Assignments/Assignment4/Training/Norm-Tissue-Images")

# %%
from pathlib import Path
 
# get the path/directory
folder_dir = "/content/drive/MyDrive/EE610-Assignments/Assignment4/Training/Norm-Tissue-Images"
 
# iterate over files in
# that directory
images = Path(folder_dir).glob('*.png')
for image in images:
     cv2_imshow(image)
     break
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-b928e7bb130f> in <module>
#       8 images = Path(folder_dir).glob('*.png')
#       9 for image in images:
# ---> 10      cv2_imshow(image)
#      11      break
#
# /usr/local/lib/python3.7/dist-packages/google/colab/patches/__init__.py in cv2_imshow(a)
#      16       image.
#      17   """
# ---> 18   a = a.clip(0, 255).astype('uint8')
#      19   # cv2 stores colors as BGR; convert to RGB
#      20   if a.ndim == 3:
#
# AttributeError: 'PosixPath' object has no attribute 'clip'

# %%
# import the modules
import os
from os import listdir

# get the path/directory
folder_dir = "/content/drive/MyDrive/EE610-Assignments/Assignment4/Training/Norm-Tissue-Images"
for images in os.listdir(folder_dir):

    # check if the image ends with png
    if (images.endswith(".png")):
      cv2_imshow(folder_dir + images) 
    
    break
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-64bdc05247ec> in <module>
#       9     # check if the image ends with png
#      10     if (images.endswith(".png")):
# ---> 11       cv2_imshow(folder_dir + images)
#      12
#      13     break
#
# /usr/local/lib/python3.7/dist-packages/google/colab/patches/__init__.py in cv2_imshow(a)
#      16       image.
#      17   """
# ---> 18   a = a.clip(0, 255).astype('uint8')
#      19   # cv2 stores colors as BGR; convert to RGB
#      20   if a.ndim == 3:
#
# AttributeError: 'str' object has no attribute 'clip'
